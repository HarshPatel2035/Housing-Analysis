# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# # Data Import and First Inspection

# %%
df = pd.read_csv("housing.csv")
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity
# 0            NEAR BAY
# 1            NEAR BAY
# 2            NEAR BAY
# 3            NEAR BAY
# 4            NEAR BAY
# ...               ...
# 20635          INLAND
# 20636          INLAND
# 20637          INLAND
# 20638          INLAND
# 20639          INLAND
#
# [20640 rows x 10 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %%
df.nunique()
# Out:
# longitude               844
# latitude                862
# housing_median_age       52
# total_rooms            5926
# total_bedrooms         1923
# population             3888
# households             1815
# median_income         12928
# median_house_value     3842
# ocean_proximity           5
# dtype: int64

# %% [markdown]
# ### Check Missing Values

# %%
df[df['total_bedrooms'].isna()]
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 290      -122.16     37.77                47.0       1256.0             NaN
# 341      -122.17     37.75                38.0        992.0             NaN
# 538      -122.28     37.78                29.0       5154.0             NaN
# 563      -122.24     37.75                45.0        891.0             NaN
# 696      -122.10     37.69                41.0        746.0             NaN
# ...          ...       ...                 ...          ...             ...
# 20267    -119.19     34.20                18.0       3620.0             NaN
# 20268    -119.18     34.19                19.0       2393.0             NaN
# 20372    -118.88     34.17                15.0       4260.0             NaN
# 20460    -118.75     34.29                17.0       5512.0             NaN
# 20484    -118.72     34.28                17.0       3051.0             NaN
#
#        population  households  median_income  median_house_value  \
# 290         570.0       218.0         4.3750            161900.0
# 341         732.0       259.0         1.6196             85100.0
# 538        3741.0      1273.0         2.5762            173400.0
# 563         384.0       146.0         4.9489            247100.0
# 696         387.0       161.0         3.9063            178400.0
# ...           ...         ...            ...                 ...
# 20267      3171.0       779.0         3.3409            220500.0
# 20268      1938.0       762.0         1.6953            167400.0
# 20372      1701.0       669.0         5.1033            410700.0
# 20460      2734.0       814.0         6.6073            258100.0
# 20484      1705.0       495.0         5.7376            218600.0
#
#       ocean_proximity
# 290          NEAR BAY
# 341          NEAR BAY
# 538          NEAR BAY
# 563          NEAR BAY
# 696          NEAR BAY
# ...               ...
# 20267      NEAR OCEAN
# 20268      NEAR OCEAN
# 20372       <1H OCEAN
# 20460       <1H OCEAN
# 20484       <1H OCEAN
#
# [207 rows x 10 columns]

# %% [markdown]
# ### Check Duplicateds

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [longitude, latitude, housing_median_age, total_rooms, total_bedrooms, population, households, median_income, median_house_value, ocean_proximity]
# Index: []

# %% [markdown]
# ### Get the Describe of `df`

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20640.000000  20640.000000   20640.000000
# mean       537.870553   1425.476744    499.539680       3.870671
# std        421.385070   1132.462122    382.329753       1.899822
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563400
# 50%        435.000000   1166.000000    409.000000       3.534800
# 75%        647.000000   1725.000000    605.000000       4.743250
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value
# count        20640.000000
# mean        206855.816909
# std         115395.615874
# min          14999.000000
# 25%         119600.000000
# 50%         179700.000000
# 75%         264725.000000
# max         500001.000000

# %% [markdown]
# ### Check the Values of some Columns

# %%
df['ocean_proximity'].value_counts()
# Out:
# ocean_proximity
# <1H OCEAN     9136
# INLAND        6551
# NEAR OCEAN    2658
# NEAR BAY      2290
# ISLAND           5
# Name: count, dtype: int64

# %%
df['total_rooms'].value_counts()
# Out:
# total_rooms
# 1527.0     18
# 1613.0     17
# 1582.0     17
# 2127.0     16
# 1717.0     15
#            ..
# 9614.0      1
# 10839.0     1
# 11872.0     1
# 6205.0      1
# 10035.0     1
# Name: count, Length: 5926, dtype: int64

# %% [markdown]
# ### Check Histogram of `df`

# %%
df.hist(bins = 50, figsize = (20,15))
plt.show()

# %% [markdown]
# # Data Cleaning and Creating Additional Features

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  float64
#  3   total_rooms         20640 non-null  float64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  float64
#  6   households          20640 non-null  float64
#  7   median_income       20640 non-null  float64
#  8   median_house_value  20640 non-null  float64
#  9   ocean_proximity     20640 non-null  object
# dtypes: float64(9), object(1)
# memory usage: 1.6+ MB

# %% [markdown]
# ### Drop NaN Values

# %%
df.dropna(inplace = True)

# %% [markdown]
# ### Add New Features
# * `roomes_per_hours`
# * `pop_per_househole`
# * `bedrooms_per_room`

# %% [markdown]
# #### `roomes_per_house`

# %%
df['rooms_per_household'] = df['total_rooms'].div(df['households'])
df['rooms_per_household'].nlargest(20)
# Out:
# 1914     141.909091
# 1979     132.533333
# 12447     62.422222
# 1913      61.812500
# 11862     59.875000
# 1912      56.269231
# 9676      52.848214
# 11707     52.690476
# 2395      50.837838
# 1240      47.515152
# 11832     41.333333
# 11833     39.755906
# 1872      38.840909
# 20094     37.063492
# 1926      37.000000
# 13950     36.715385
# 10080     36.478261
# 11716     36.075472
# 13965     36.060606
# 1978      34.843750
# Name: rooms_per_household, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 11 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   longitude            20433 non-null  float64
#  1   latitude             20433 non-null  float64
#  2   housing_median_age   20433 non-null  float64
#  3   total_rooms          20433 non-null  float64
#  4   total_bedrooms       20433 non-null  float64
#  5   population           20433 non-null  float64
#  6   households           20433 non-null  float64
#  7   median_income        20433 non-null  float64
#  8   median_house_value   20433 non-null  float64
#  9   ocean_proximity      20433 non-null  object
#  10  rooms_per_household  20433 non-null  float64
# dtypes: float64(10), object(1)
# memory usage: 2.4+ MB

# %%
df['rooms_per_household'].nsmallest(20)
# Out:
# 5916     0.846154
# 8219     0.888889
# 3126     1.000000
# 14818    1.130435
# 17820    1.130435
# 4552     1.260870
# 4550     1.378486
# 4587     1.411290
# 4602     1.465753
# 12484    1.550409
# 9319     1.553030
# 4585     1.598131
# 4862     1.625514
# 2779     1.629630
# 4424     1.640000
# 4583     1.654440
# 4592     1.678571
# 4639     1.680774
# 4601     1.708995
# 73       1.714286
# Name: rooms_per_household, dtype: float64

# %%
df.loc[[1979, 5916, 8219]]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1979    -120.08     38.80                34.0       1988.0           511.0
# 5916    -118.44     34.28                46.0         11.0            11.0
# 8219    -118.21     33.79                33.0         32.0            18.0
#
#       population  households  median_income  median_house_value  \
# 1979        36.0        15.0         4.6250            162500.0
# 5916        24.0        13.0         2.8750            162500.0
# 8219        96.0        36.0         4.5938            112500.0
#
#      ocean_proximity  rooms_per_household
# 1979          INLAND           132.533333
# 5916       <1H OCEAN             0.846154
# 8219      NEAR OCEAN             0.888889

# %% [markdown]
# #### `pop_per_household`

# %%
df['pop_per_household'] = df['population'].div(df['households'])
df['pop_per_household']
# Out:
# 0        2.555556
# 1        2.109842
# 2        2.802260
# 3        2.547945
# 4        2.181467
#            ...
# 20635    2.560606
# 20636    3.122807
# 20637    2.325635
# 20638    2.123209
# 20639    2.616981
# Name: pop_per_household, Length: 20433, dtype: float64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 12 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   longitude            20433 non-null  float64
#  1   latitude             20433 non-null  float64
#  2   housing_median_age   20433 non-null  float64
#  3   total_rooms          20433 non-null  float64
#  4   total_bedrooms       20433 non-null  float64
#  5   population           20433 non-null  float64
#  6   households           20433 non-null  float64
#  7   median_income        20433 non-null  float64
#  8   median_house_value   20433 non-null  float64
#  9   ocean_proximity      20433 non-null  object
#  10  rooms_per_household  20433 non-null  float64
#  11  pop_per_household    20433 non-null  float64
# dtypes: float64(11), object(1)
# memory usage: 2.5+ MB

# %% [markdown]
# #### `bedrooms_per_room`

# %%
df['bedrooms_per_room']= df['total_bedrooms'].div(df['total_rooms'])
df['bedrooms_per_room']
# Out:
# 0        0.146591
# 1        0.155797
# 2        0.129516
# 3        0.184458
# 4        0.172096
#            ...
# 20635    0.224625
# 20636    0.215208
# 20637    0.215173
# 20638    0.219892
# 20639    0.221185
# Name: bedrooms_per_room, Length: 20433, dtype: float64

# %% [markdown]
# _____________________

# %%
df.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20433.000000  20433.000000        20433.000000  20433.000000
# mean    -119.570689     35.633221           28.633094   2636.504233
# std        2.003578      2.136348           12.591805   2185.269567
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1450.000000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.720000           37.000000   3143.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population    households  median_income  \
# count    20433.000000  20433.000000  20433.000000   20433.000000
# mean       537.870553   1424.946949    499.433465       3.871162
# std        421.385070   1133.208490    382.299226       1.899291
# min          1.000000      3.000000      1.000000       0.499900
# 25%        296.000000    787.000000    280.000000       2.563700
# 50%        435.000000   1166.000000    409.000000       3.536500
# 75%        647.000000   1722.000000    604.000000       4.744000
# max       6445.000000  35682.000000   6082.000000      15.000100
#
#        median_house_value  rooms_per_household  pop_per_household  \
# count        20433.000000         20433.000000       20433.000000
# mean        206864.413155             5.431344           3.071533
# std         115435.667099             2.482946          10.438269
# min          14999.000000             0.846154           0.692308
# 25%         119500.000000             4.441441           2.429032
# 50%         179700.000000             5.230769           2.817582
# 75%         264700.000000             6.052381           3.281513
# max         500001.000000           141.909091        1243.333333
#
#        bedrooms_per_room
# count       20433.000000
# mean            0.213039
# std             0.057983
# min             0.100000
# 25%             0.175427
# 50%             0.203162
# 75%             0.239821
# max             1.000000

# %% [markdown]
# # Which Factors Influence House Prices

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity  rooms_per_household  pop_per_household  \
# 0            NEAR BAY             6.984127           2.555556
# 1            NEAR BAY             6.238137           2.109842
# 2            NEAR BAY             8.288136           2.802260
# 3            NEAR BAY             5.817352           2.547945
# 4            NEAR BAY             6.281853           2.181467
# ...               ...                  ...                ...
# 20635          INLAND             5.045455           2.560606
# 20636          INLAND             6.114035           3.122807
# 20637          INLAND             5.205543           2.325635
# 20638          INLAND             5.329513           2.123209
# 20639          INLAND             5.254717           2.616981
#
#        bedrooms_per_room
# 0               0.146591
# 1               0.155797
# 2               0.129516
# 3               0.184458
# 4               0.172096
# ...                  ...
# 20635           0.224625
# 20636           0.215208
# 20637           0.215173
# 20638           0.219892
# 20639           0.221185
#
# [20433 rows x 13 columns]

# %% [markdown]
# ### Check the Hist of `median_house_value`

# %%
df['median_house_value'].hist(bins= 100, figsize = (12,8))
plt.show()

# %% [markdown]
# ### Check the Correalation

# %% [markdown]
# __Calculate__ the __Correlation__ between "median_house_value" and all features. Which factors seems to influence house prices/values?

# %%
numeric_columns = df.select_dtypes(include=[np.number]).columns
correlation = df[numeric_columns].corr()
correlation['median_house_value'].sort_values(ascending=False)
# Out:
# median_house_value     1.000000
# median_income          0.688355
# rooms_per_household    0.151344
# total_rooms            0.133294
# housing_median_age     0.106432
# households             0.064894
# total_bedrooms         0.049686
# pop_per_household     -0.023639
# population            -0.025300
# longitude             -0.045398
# latitude              -0.144638
# bedrooms_per_room     -0.255880
# Name: median_house_value, dtype: float64

# %% [markdown]
# ### Check Hist of `median_income`

# %%
df['median_income'].hist(bins = 100, figsize = (12,8))
plt.show()

# %% [markdown]
# ### Plotting `Population` & `median_house_value` on map

# %%
df.plot(kind = 'scatter', x = 'longitude', y = 'latitude',
        s= df['population']/ 100, label = 'Population', figsize = (15, 10),
        c = "median_house_value", cmap = "coolwarm", colorbar = True,
        alpha = 0.4, fontsize =15, sharex = False)
plt.ylabel("Latitude", fontsize = 14)
plt.xlabel("Longtitud", fontsize = 14)
plt.legend(fontsize = 16)
plt.show()

# %%
import matplotlib.image as mpimg
california_img = mpimg.imread('california.png')
california_img
# Out:
# array([[[0.627451 , 0.7764706, 0.9137255, 1.       ],
#         [0.627451 , 0.7764706, 0.9137255, 1.       ],
#         [0.627451 , 0.7764706, 0.9137255, 1.       ],
#         ...,
#         [0.9647059, 0.827451 , 0.6666667, 1.       ],
#         [0.9647059, 0.827451 , 0.6666667, 1.       ],
#         [0.9647059, 0.827451 , 0.6666667, 1.       ]],
#
#        [[0.627451 , 0.7764706, 0.9137255, 1.       ],
#         [0.627451 , 0.7764706, 0.9137255, 1.       ],
#         [0.627451 , 0.7764706, 0.9137255, 1.       ],
#         ...,
#         [0.9647059, 0.827451 , 0.6666667, 1.       ],
#         [0.9647059, 0.827451 , 0.6666667, 1.       ],
#         [0.9647059, 0.827451 , 0.6666667, 1.       ]],
#
#        [[0.627451 , 0.7764706, 0.9137255, 1.       ],
#         [0.627451 , 0.7764706, 0.9137255, 1.       ],
#         [0.627451 , 0.7764706, 0.9137255, 1.       ],
#         ...,
#         [0.9647059, 0.827451 , 0.6666667, 1.       ],
#         [0.9647059, 0.827451 , 0.6666667, 1.       ],
#         [0.9647059, 0.827451 , 0.6666667, 1.       ]],
#
#        ...,
#
#        [[0.627451 , 0.7764706, 0.9137255, 1.       ],
#         [0.627451 , 0.7764706, 0.9137255, 1.       ],
#         [0.627451 , 0.7764706, 0.9137255, 1.       ],
#         ...,
#         [0.9647059, 0.827451 , 0.6666667, 1.       ],
#         [0.9647059, 0.827451 , 0.6666667, 1.       ],
#         [0.9647059, 0.827451 , 0.6666667, 1.       ]],
#
#        [[0.627451 , 0.7764706, 0.9137255, 1.       ],
#         [0.627451 , 0.7764706, 0.9137255, 1.       ],
#         [0.627451 , 0.7764706, 0.9137255, 1.       ],
#         ...,
#         [0.9647059, 0.827451 , 0.6666667, 1.       ],
#         [0.9647059, 0.827451 , 0.6666667, 1.       ],
#         [0.9647059, 0.827451 , 0.6666667, 1.       ]],
#
#        [[0.627451 , 0.7764706, 0.9137255, 1.       ],
#         [0.627451 , 0.7764706, 0.9137255, 1.       ],
#         [0.627451 , 0.7764706, 0.9137255, 1.       ],
#         ...,
#         [0.9647059, 0.827451 , 0.6666667, 1.       ],
#         [0.9647059, 0.827451 , 0.6666667, 1.       ],
#         [0.9647059, 0.827451 , 0.6666667, 1.       ]]],
#       shape=(674, 594, 4), dtype=float32)

# %% [markdown]
# ### Plotting Map of California

# %%
plt.figure(figsize= (15, 10))
plt.imshow(california_img)
plt.show()

# %%
plt.figure(figsize=(15,10))
plt.imshow(california_img, extent= [-124.55, -133.80, 32.45, 42.05])
plt.show()

# %% [markdown]
# ### Combine California map with `dot points map`

# %%
df.plot(kind = 'scatter', x = 'longitude', y = 'latitude',
        s= df['population']/ 100, label = 'Population', figsize = (15, 10),
        c = "median_house_value", cmap = "coolwarm", colorbar = True,
        alpha = 0.4, fontsize =15, sharex = False)
plt.imshow(california_img, extent= [-124.55, -113.80, 32.45, 42.05], alpha = 0.5, 
          cmap = plt.get_cmap("jet"))

plt.ylabel("Latitude", fontsize = 14)
plt.xlabel("Longtitud", fontsize = 14)
plt.legend(fontsize = 16)
plt.show()

# %%
prox = df['ocean_proximity'].unique()
prox
# Out:
# array(['NEAR BAY', '<1H OCEAN', 'INLAND', 'NEAR OCEAN', 'ISLAND'],
#       dtype=object)

# %%
df_loc = df[df['ocean_proximity'] == prox[3]].copy()

# %%
df_loc.plot(kind = "scatter", x = 'longitude', y = 'latitude',
           s = df_loc['population']/100, label = 'Population', figsize = (15, 10),
            c = "median_house_value", cmap = "coolwarm",
           colorbar = True, alpha = 0.4, fontsize = 20, sharex = False)
plt.imshow(california_img, extent = [-124.55, -113.80, 32.45, 42.05], alpha = 0.5,
          cmap = plt.get_cmap("jet"))

plt.ylabel("Latitude", fontsize = 14)
plt.xlabel("Longitude", fontsize = 14)
plt.legend(fontsize = 16)
plt.show()

# %%
df_loc2 = df[df['ocean_proximity'] == prox[2]].copy()

# %%
df_loc2.plot(kind = "scatter", x = 'longitude', y = 'latitude',
           s = df_loc2['population']/100, label = 'Population', figsize = (15, 10),
            c = "median_house_value", cmap = "coolwarm",
           colorbar = True, alpha = 0.4, fontsize = 20, sharex = False)
plt.imshow(california_img, extent = [-124.55, -113.80, 32.45, 42.05], alpha = 0.5,
          cmap = plt.get_cmap("jet"))

plt.ylabel("Latitude", fontsize = 14)
plt.xlabel("Longitude", fontsize = 14)
plt.legend(fontsize = 16)
plt.show()

# %%
df_loc3 = df[df['ocean_proximity'] == prox[1]].copy()

# %%
df_loc3.plot(kind = "scatter", x = 'longitude', y = 'latitude',
           s = df_loc3['population']/100, label = 'Population', figsize = (15, 10),
            c = "median_house_value", cmap = "coolwarm",
           colorbar = True, alpha = 0.4, fontsize = 20, sharex = False)
plt.imshow(california_img, extent = [-124.55, -113.80, 32.45, 42.05], alpha = 0.5,
          cmap = plt.get_cmap("jet"))

plt.ylabel("Latitude", fontsize = 14)
plt.xlabel("Longitude", fontsize = 14)
plt.legend(fontsize = 16)
plt.show()

# %%
df
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  median_house_value  \
# 0           322.0       126.0         8.3252            452600.0
# 1          2401.0      1138.0         8.3014            358500.0
# 2           496.0       177.0         7.2574            352100.0
# 3           558.0       219.0         5.6431            341300.0
# 4           565.0       259.0         3.8462            342200.0
# ...           ...         ...            ...                 ...
# 20635       845.0       330.0         1.5603             78100.0
# 20636       356.0       114.0         2.5568             77100.0
# 20637      1007.0       433.0         1.7000             92300.0
# 20638       741.0       349.0         1.8672             84700.0
# 20639      1387.0       530.0         2.3886             89400.0
#
#       ocean_proximity  rooms_per_household  pop_per_household  \
# 0            NEAR BAY             6.984127           2.555556
# 1            NEAR BAY             6.238137           2.109842
# 2            NEAR BAY             8.288136           2.802260
# 3            NEAR BAY             5.817352           2.547945
# 4            NEAR BAY             6.281853           2.181467
# ...               ...                  ...                ...
# 20635          INLAND             5.045455           2.560606
# 20636          INLAND             6.114035           3.122807
# 20637          INLAND             5.205543           2.325635
# 20638          INLAND             5.329513           2.123209
# 20639          INLAND             5.254717           2.616981
#
#        bedrooms_per_room
# 0               0.146591
# 1               0.155797
# 2               0.129516
# 3               0.184458
# 4               0.172096
# ...                  ...
# 20635           0.224625
# 20636           0.215208
# 20637           0.215173
# 20638           0.219892
# 20639           0.221185
#
# [20433 rows x 13 columns]

# %% [markdown]
# ### hist of `median_income` column

# %%
df['median_income'].hist(bins= 100, figsize = (15, 10))
plt.title("Median Income")
plt.show()

# %% [markdown]
# # Feature Engineering

# %%
label = df['median_house_value'].copy()
label
# Out:
# 0        452600.0
# 1        358500.0
# 2        352100.0
# 3        341300.0
# 4        342200.0
#            ...
# 20635     78100.0
# 20636     77100.0
# 20637     92300.0
# 20638     84700.0
# 20639     89400.0
# Name: median_house_value, Length: 20433, dtype: float64

# %%
features = df.drop(columns= ['median_house_value'])
features
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity  \
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
#        rooms_per_household  pop_per_household  bedrooms_per_room
# 0                 6.984127           2.555556           0.146591
# 1                 6.238137           2.109842           0.155797
# 2                 8.288136           2.802260           0.129516
# 3                 5.817352           2.547945           0.184458
# 4                 6.281853           2.181467           0.172096
# ...                    ...                ...                ...
# 20635             5.045455           2.560606           0.224625
# 20636             6.114035           3.122807           0.215208
# 20637             5.205543           2.325635           0.215173
# 20638             5.329513           2.123209           0.219892
# 20639             5.254717           2.616981           0.221185
#
# [20433 rows x 12 columns]

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20433 entries, 0 to 20639
# Data columns (total 13 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   longitude            20433 non-null  float64
#  1   latitude             20433 non-null  float64
#  2   housing_median_age   20433 non-null  float64
#  3   total_rooms          20433 non-null  float64
#  4   total_bedrooms       20433 non-null  float64
#  5   population           20433 non-null  float64
#  6   households           20433 non-null  float64
#  7   median_income        20433 non-null  float64
#  8   ocean_proximity      20433 non-null  object
#  9   rooms_per_household  20433 non-null  float64
#  10  pop_per_household    20433 non-null  float64
#  11  bedrooms_per_room    20433 non-null  float64
#  12  income_cat           20433 non-null  category
# dtypes: category(1), float64(11), object(1)
# memory usage: 2.6+ MB

# %%
features.select_dtypes('float')
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income  rooms_per_household  \
# 0           322.0       126.0         8.3252             6.984127
# 1          2401.0      1138.0         8.3014             6.238137
# 2           496.0       177.0         7.2574             8.288136
# 3           558.0       219.0         5.6431             5.817352
# 4           565.0       259.0         3.8462             6.281853
# ...           ...         ...            ...                  ...
# 20635       845.0       330.0         1.5603             5.045455
# 20636       356.0       114.0         2.5568             6.114035
# 20637      1007.0       433.0         1.7000             5.205543
# 20638       741.0       349.0         1.8672             5.329513
# 20639      1387.0       530.0         2.3886             5.254717
#
#        pop_per_household  bedrooms_per_room
# 0               2.555556           0.146591
# 1               2.109842           0.155797
# 2               2.802260           0.129516
# 3               2.547945           0.184458
# 4               2.181467           0.172096
# ...                  ...                ...
# 20635           2.560606           0.224625
# 20636           3.122807           0.215208
# 20637           2.325635           0.215173
# 20638           2.123209           0.219892
# 20639           2.616981           0.221185
#
# [20433 rows x 11 columns]

# %% [markdown]
# # Spliting The Data Into Train And Test Set

# %%
features
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity  \
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
#        rooms_per_household  pop_per_household  bedrooms_per_room
# 0                 6.984127           2.555556           0.146591
# 1                 6.238137           2.109842           0.155797
# 2                 8.288136           2.802260           0.129516
# 3                 5.817352           2.547945           0.184458
# 4                 6.281853           2.181467           0.172096
# ...                    ...                ...                ...
# 20635             5.045455           2.560606           0.224625
# 20636             6.114035           3.122807           0.215208
# 20637             5.205543           2.325635           0.215173
# 20638             5.329513           2.123209           0.219892
# 20639             5.254717           2.616981           0.221185
#
# [20433 rows x 12 columns]

# %% [markdown]
# ### Create X_test

# %%
test_size = 0.2

# %%
X_test = features.sample(frac= test_size, random_state= 123)

# %%
X_test
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 14354    -117.23     32.75                23.0       2415.0           653.0
# 12908    -121.29     38.63                24.0       2868.0           527.0
# 19545    -120.97     37.63                39.0       2360.0           607.0
# 12188    -117.35     33.69                11.0       1229.0           236.0
# 14786    -117.12     32.57                21.0       1738.0           295.0
# ...          ...       ...                 ...          ...             ...
# 10262    -117.86     33.88                20.0       3977.0           540.0
# 3614     -118.41     34.24                38.0        490.0           101.0
# 19296    -122.82     38.40                40.0       2406.0           423.0
# 5826     -118.30     34.19                52.0       1704.0           277.0
# 15383    -117.20     33.38                14.0       5392.0           821.0
#
#        population  households  median_income ocean_proximity  \
# 14354      1275.0       596.0         3.1389      NEAR OCEAN
# 12908      1284.0       487.0         3.3182          INLAND
# 19545      2047.0       605.0         1.7054          INLAND
# 12188       581.0       190.0         3.1020       <1H OCEAN
# 14786       983.0       298.0         4.8274      NEAR OCEAN
# ...           ...         ...            ...             ...
# 10262      1886.0       541.0         6.5843       <1H OCEAN
# 3614        402.0       100.0         3.1250       <1H OCEAN
# 19296      1054.0       426.0         3.8846       <1H OCEAN
# 5826        746.0       262.0         4.7986       <1H OCEAN
# 15383      2350.0       810.0         5.0507       <1H OCEAN
#
#        rooms_per_household  pop_per_household  bedrooms_per_room
# 14354             4.052013           2.139262           0.270393
# 12908             5.889117           2.636550           0.183752
# 19545             3.900826           3.383471           0.257203
# 12188             6.468421           3.057895           0.192026
# 14786             5.832215           3.298658           0.169735
# ...                    ...                ...                ...
# 10262             7.351201           3.486137           0.135781
# 3614              4.900000           4.020000           0.206122
# 19296             5.647887           2.474178           0.175810
# 5826              6.503817           2.847328           0.162559
# 15383             6.656790           2.901235           0.152263
#
# [4087 rows x 12 columns]

# %%
X_test.index
# Out:
# Index([14354, 12908, 19545, 12188, 14786,  9941,  3179,  4650, 15550, 17190,
#        ...
#         3992, 10261, 10862, 10863, 13864, 10262,  3614, 19296,  5826, 15383],
#       dtype='int64', length=4087)

# %% [markdown]
# ### Create X_training

# %%
X_train = features.loc[~features.index.isin(X_test.index)].copy()

# %%
X_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                41.0        880.0           129.0
# 1        -122.22     37.86                21.0       7099.0          1106.0
# 2        -122.24     37.85                52.0       1467.0           190.0
# 3        -122.25     37.85                52.0       1274.0           235.0
# 4        -122.25     37.85                52.0       1627.0           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                25.0       1665.0           374.0
# 20636    -121.21     39.49                18.0        697.0           150.0
# 20637    -121.22     39.43                17.0       2254.0           485.0
# 20638    -121.32     39.43                18.0       1860.0           409.0
# 20639    -121.24     39.37                16.0       2785.0           616.0
#
#        population  households  median_income ocean_proximity  \
# 0           322.0       126.0         8.3252        NEAR BAY
# 1          2401.0      1138.0         8.3014        NEAR BAY
# 2           496.0       177.0         7.2574        NEAR BAY
# 3           558.0       219.0         5.6431        NEAR BAY
# 4           565.0       259.0         3.8462        NEAR BAY
# ...           ...         ...            ...             ...
# 20635       845.0       330.0         1.5603          INLAND
# 20636       356.0       114.0         2.5568          INLAND
# 20637      1007.0       433.0         1.7000          INLAND
# 20638       741.0       349.0         1.8672          INLAND
# 20639      1387.0       530.0         2.3886          INLAND
#
#        rooms_per_household  pop_per_household  bedrooms_per_room
# 0                 6.984127           2.555556           0.146591
# 1                 6.238137           2.109842           0.155797
# 2                 8.288136           2.802260           0.129516
# 3                 5.817352           2.547945           0.184458
# 4                 6.281853           2.181467           0.172096
# ...                    ...                ...                ...
# 20635             5.045455           2.560606           0.224625
# 20636             6.114035           3.122807           0.215208
# 20637             5.205543           2.325635           0.215173
# 20638             5.329513           2.123209           0.219892
# 20639             5.254717           2.616981           0.221185
#
# [16346 rows x 12 columns]

# %%
X_train = X_train.sample(frac = 1, random_state=123)
X_train
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 9896     -122.26     38.29                10.0        969.0           160.0
# 6749     -118.08     34.11                42.0       2628.0           525.0
# 13825    -117.15     34.48                31.0        265.0            55.0
# 2842     -118.98     35.40                36.0       1443.0           273.0
# 10112    -117.94     33.94                30.0       1596.0           307.0
# ...          ...       ...                 ...          ...             ...
# 15460    -117.29     33.15                11.0       2560.0           445.0
# 1689     -122.26     38.02                 5.0       3846.0           786.0
# 14698    -117.09     32.79                31.0       2019.0           417.0
# 19870    -119.36     36.33                11.0       3221.0           617.0
# 4461     -118.18     34.10                 7.0       2529.0           689.0
#
#        population  households  median_income ocean_proximity  \
# 9896        482.0       180.0         6.5799        NEAR BAY
# 6749       1494.0       523.0         3.9464       <1H OCEAN
# 13825       186.0        55.0         2.1250          INLAND
# 2842        680.0       259.0         2.9821          INLAND
# 10112       845.0       309.0         4.5096       <1H OCEAN
# ...           ...         ...            ...             ...
# 15460       952.0       448.0         4.0625      NEAR OCEAN
# 1689       2053.0       716.0         5.0473        NEAR BAY
# 14698       872.0       386.0         3.1964      NEAR OCEAN
# 19870      1351.0       565.0         2.9844          INLAND
# 4461       1215.0       577.0         4.7853       <1H OCEAN
#
#        rooms_per_household  pop_per_household  bedrooms_per_room
# 9896              5.383333           2.677778           0.165119
# 6749              5.024857           2.856597           0.199772
# 13825             4.818182           3.381818           0.207547
# 2842              5.571429           2.625483           0.189189
# 10112             5.165049           2.734628           0.192356
# ...                    ...                ...                ...
# 15460             5.714286           2.125000           0.173828
# 1689              5.371508           2.867318           0.204368
# 14698             5.230570           2.259067           0.206538
# 19870             5.700885           2.391150           0.191555
# 4461              4.383016           2.105719           0.272440
#
# [16346 rows x 12 columns]

# %% [markdown]
# ### y_traing & y_test

# %%
y_train = label.loc[X_train.index]
y_test = label.loc[X_test.index]
